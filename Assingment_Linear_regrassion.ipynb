# %% [markdown]
# <a href="https://colab.research.google.com/github/ShourovyAkter/Assingment-of-Machine-Learning/blob/main/Assingment_Linear_regrassion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv('/content/drive/MyDrive/dataset/Housing.csv')

# %%
df
# Out:
#         price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    13300000  7420         4          2        3      yes        no       no
# 1    12250000  8960         4          4        4      yes        no       no
# 2    12250000  9960         3          2        2      yes        no      yes
# 3    12215000  7500         4          2        2      yes        no      yes
# 4    11410000  7420         4          1        2      yes       yes      yes
# ..        ...   ...       ...        ...      ...      ...       ...      ...
# 540   1820000  3000         2          1        1      yes        no      yes
# 541   1767150  2400         3          1        1       no        no       no
# 542   1750000  3620         2          1        1      yes        no       no
# 543   1750000  2910         3          1        1       no        no       no
# 544   1750000  3850         3          1        2      yes        no       no
#
# ...

# %%
df.head()
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420         4          2        3      yes        no       no
# 1  12250000  8960         4          4        4      yes        no       no
# 2  12250000  9960         3          2        2      yes        no      yes
# 3  12215000  7500         4          2        2      yes        no      yes
# 4  11410000  7420         4          1        2      yes       yes      yes
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0              no             yes        2      yes        furnished
# 1              no             yes        3       no        furnished
# 2              no              no        2      yes   semi-furnished
# 3              no             yes        3      yes        furnished
# 4              no             yes        2       no        furnished

# %%
df.isnull().sum()
# Out:
# price               0
# area                0
# bedrooms            0
# bathrooms           0
# stories             0
# mainroad            0
# guestroom           0
# basement            0
# hotwaterheating     0
# airconditioning     0
# parking             0
# prefarea            0
# furnishingstatus    0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 545 entries, 0 to 544
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   price             545 non-null    int64
#  1   area              545 non-null    int64
#  2   bedrooms          545 non-null    int64
#  3   bathrooms         545 non-null    int64
#  4   stories           545 non-null    int64
#  5   mainroad          545 non-null    object
#  6   guestroom         545 non-null    object
#  7   basement          545 non-null    object
#  8   hotwaterheating   545 non-null    object
#  9   airconditioning   545 non-null    object
#  10  parking           545 non-null    int64
#  11  prefarea          545 non-null    object
#  12  furnishingstatus  545 non-null    object
# dtypes: int64(6), object(7)
# memory usage: 55.5+ KB

# %%
df.describe()
# Out:
#               price          area    bedrooms   bathrooms     stories  \
# count  5.450000e+02    545.000000  545.000000  545.000000  545.000000
# mean   4.766729e+06   5150.541284    2.965138    1.286239    1.805505
# std    1.870440e+06   2170.141023    0.738064    0.502470    0.867492
# min    1.750000e+06   1650.000000    1.000000    1.000000    1.000000
# 25%    3.430000e+06   3600.000000    2.000000    1.000000    1.000000
# 50%    4.340000e+06   4600.000000    3.000000    1.000000    2.000000
# 75%    5.740000e+06   6360.000000    3.000000    2.000000    2.000000
# max    1.330000e+07  16200.000000    6.000000    4.000000    4.000000
#
#           parking
# count  545.000000
# mean     0.693578
# std      0.861586
# min      0.000000
# 25%      0.000000
# 50%      0.000000
# 75%      1.000000
# max      3.000000

# %%
plt.scatter(df['price'],df['area'])
plt.xlabel('price')
plt.ylabel('area')
plt.title('House price prediction')
# Out:
# Text(0.5, 1.0, 'House price prediction')

# %%
x = df['price']
x
# Out:
# 0      13300000
# 1      12250000
# 2      12250000
# 3      12215000
# 4      11410000
#          ...
# 540     1820000
# 541     1767150
# 542     1750000
# 543     1750000
# 544     1750000
# Name: price, Length: 545, dtype: int64

# %%
x.head()
# Out:
# 0    13300000
# 1    12250000
# 2    12250000
# 3    12215000
# 4    11410000
# Name: price, dtype: int64

# %%
y = df['area']
y
# Out:
# 0      7420
# 1      8960
# 2      9960
# 3      7500
# 4      7420
#        ...
# 540    3000
# 541    2400
# 542    3620
# 543    2910
# 544    3850
# Name: area, Length: 545, dtype: int64

# %%
y.head()
# Out:
# 0    7420
# 1    8960
# 2    9960
# 3    7500
# 4    7420
# Name: area, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=.30,random_state=1)

# %%
x_test
# Out:
# 62     7070000
# 247    4550000
# 142    5600000
# 107    6125000
# 483    2940000
#         ...
# 450    3150000
# 542    1750000
# 408    3430000
# 80     6629000
# 46     7525000
# Name: price, Length: 164, dtype: int64

# %%
x_train
# Out:
# 180    5215000
# 189    5040000
# 93     6300000
# 444    3220000
# 81     6615000
#         ...
# 129    5873000
# 144    5600000
# 72     6720000
# 235    4620000
# 37     7980000
# Name: price, Length: 381, dtype: int64

# %%
y_test
# Out:
# 62      6240
# 247     8400
# 142    10500
# 107     6420
# 483     6615
#        ...
# 450     3450
# 542     3620
# 408     4000
# 80      6000
# 46      6000
# Name: area, Length: 164, dtype: int64

# %%
y_train
# Out:
# 180     4500
# 189     3540
# 93      7200
# 444     3120
# 81      4000
#        ...
# 129    11460
# 144     4700
# 72      5020
# 235     5680
# 37      9000
# Name: area, Length: 381, dtype: int64

# %%
from sklearn.linear_model import LinearRegression

# %%
reg = LinearRegression()

# %%
x.mean()
# Out:
# 4766729.247706422

# %%
y.mean()
# Out:
# 5150.54128440367

# %%
plt.scatter(x.mean(),y.mean(),marker='*')
plt.scatter(df['price'],df['area'],color='red')
plt.xlabel('price')
plt.ylabel('area')
plt.title('House price prediction')
# Out:
# Text(0.5, 1.0, 'House price prediction')

# %%
reg.fit(df[['price']],df[['area']])
# Out:
# LinearRegression()

# %%
m = reg.coef_
m
# Out:
# array([[0.00062188]])

# %%
c = reg.intercept_
c
# Out:
# array([2186.20555954])

# %%
m*13300000+c
# Out:
# array([[10457.21553135]])

# %%
reg.predict([[13300000]])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[10457.21553135]])

# %%
df['predict_y'] = reg.predict(df[['price']])
df.head()
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420         4          2        3      yes        no       no
# 1  12250000  8960         4          4        4      yes        no       no
# 2  12250000  9960         3          2        2      yes        no      yes
# 3  12215000  7500         4          2        2      yes        no      yes
# 4  11410000  7420         4          1        2      yes       yes      yes
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus  \
# 0              no             yes        2      yes        furnished
# 1              no             yes        3       no        furnished
# 2              no              no        2      yes   semi-furnished
# 3              no             yes        3      yes        furnished
# 4              no             yes        2       no        furnished
#
#       predict_y
# 0  10457.215531
# 1   9804.241060
# 2   9804.241060
# 3   9782.475244
# ...

# %%
plt.plot(df[['price']],reg.predict(df[['price']]))
plt.scatter(x.mean(),y.mean())
plt.scatter(df['price'],df['area'])
plt.xlabel('price')
plt.ylabel('area')
plt.title('House price prediction')
# Out:
# Text(0.5, 1.0, 'House price prediction')
