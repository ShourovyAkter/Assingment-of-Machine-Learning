# %% [markdown]
# <a href="https://colab.research.google.com/github/ShourovyAkter/Assingment-of-Machine-Learning/blob/main/Logistic_Regrassion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/content/drive/MyDrive/data/logistricsdataset1.csv')

# %%
df
# Out:
#     Age  Status
# 0    21     0.0
# 1    33     1.0
# 2    24     0.0
# 3    28     1.0
# 4    17     0.0
# 5    33     1.0
# 6    23     0.0
# 7    30     0.0
# 8    29     1.0
# 9    22     0.0
# 10   26     1.0
# 11   20     0.0
# 12   22     0.0
# 13   24     NaN
# 14   34     1.0
# 15   29     1.0
# 16   16     0.0
# 17   18     0.0
# 18   26     1.0
# 19   25     1.0

# %%
df.isnull().sum()
# Out:
# Age       0
# Status    1
# dtype: int64

# %%
handle = df['Status'].median()

# %%
handle
# Out:
# 0.0

# %%
df.Status = df.Status.fillna(handle)

# %%
df
# Out:
#     Age  Status
# 0    21     0.0
# 1    33     1.0
# 2    24     0.0
# 3    28     1.0
# 4    17     0.0
# 5    33     1.0
# 6    23     0.0
# 7    30     0.0
# 8    29     1.0
# 9    22     0.0
# 10   26     1.0
# 11   20     0.0
# 12   22     0.0
# 13   24     0.0
# 14   34     1.0
# 15   29     1.0
# 16   16     0.0
# 17   18     0.0
# 18   26     1.0
# 19   25     1.0

# %%
df['Status'].value_counts()
# Out:
# 0.0    11
# 1.0     9
# Name: Status, dtype: int64

# %%
x = df[['Age']]

# %%
x
# Out:
#     Age
# 0    21
# 1    33
# 2    24
# 3    28
# 4    17
# 5    33
# 6    23
# 7    30
# 8    29
# 9    22
# 10   26
# 11   20
# 12   22
# 13   24
# 14   34
# 15   29
# 16   16
# 17   18
# 18   26
# 19   25

# %%
y = df['Status']

# %%
y
# Out:
# 0     0.0
# 1     1.0
# 2     0.0
# 3     1.0
# 4     0.0
# 5     1.0
# 6     0.0
# 7     0.0
# 8     1.0
# 9     0.0
# 10    1.0
# 11    0.0
# 12    0.0
# 13    0.0
# 14    1.0
# 15    1.0
# 16    0.0
# 17    0.0
# 18    1.0
# 19    1.0
# Name: Status, dtype: float64

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=.30,random_state=1)

# %%
x_train
# Out:
#     Age
# 4    17
# 17   18
# 7    30
# 1    33
# 13   24
# 0    21
# 19   25
# 18   26
# 9    22
# 15   29
# 8    29
# 12   22
# 11   20
# 5    33

# %%
x_test
# Out:
#     Age
# 3    28
# 16   16
# 6    23
# 10   26
# 2    24
# 14   34

# %%
y_test
# Out:
# 3     1.0
# 16    0.0
# 6     0.0
# 10    1.0
# 2     0.0
# 14    1.0
# Name: Status, dtype: float64

# %%
y_train
# Out:
# 4     0.0
# 17    0.0
# 7     0.0
# 1     1.0
# 13    0.0
# 0     0.0
# 19    1.0
# 18    1.0
# 9     0.0
# 15    1.0
# 8     1.0
# 12    0.0
# 11    0.0
# 5     1.0
# Name: Status, dtype: float64

# %%
from sklearn.linear_model import LogisticRegression

# %%
model = LogisticRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
model.predict(x_test)
# Out:
# array([1., 0., 0., 0., 0., 1.])

# %%
model.score(x_test,y_test)
# Out:
# 0.8333333333333334

# %%
model.predict_proba(x_test)
# Out:
# array([[0.28697051, 0.71302949],
#        [0.9902967 , 0.0097033 ],
#        [0.80161052, 0.19838948],
#        [0.50311753, 0.49688247],
#        [0.71810555, 0.28189445],
#        [0.02465085, 0.97534915]])

# %%
plt.plot(df['Age'],df['Status'])
plt.scatter(df['Age'],df['Status'])
plt.title('Plot of Logistics Regrassion')
plt.xlabel('Age')
plt.ylabel('Status')
# Out:
# Text(0, 0.5, 'Status')
